# %% [markdown]
# <a href="https://colab.research.google.com/github/harship123-source/Pfizer-Advanced-AI-Powered-Document-Insights-Data-Extraction-Externship/blob/main/Chatbot_with_LlamaIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-On – Build a Simple Chatbot with LlamaIndex
#
# Let’s get hands-on and build our first chatbot using LlamaIndex. This will be a very simple chatbot—it won’t retrieve documents yet, but it will generate responses using qroq as the language model.
#
# Before we dive in, here’s what we’re aiming for:
#
# 🟢 What We’ll Do:
#
#   1. Set up LlamaIndex + qroq to create a chatbot.
#   2. Use qroq to generate responses from user input.
#   3. Test our chatbot by asking it different questions.

# %% [markdown]
# ##  Step 1: Install Dependencies

# %%
# Install required libraries
# !pip install -q llama-index-llms-groq

# %% [markdown]
# ## Step 2: Set Up Your qroq API Key

# %%
# Set API key (replace with your actual API key)
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %% [markdown]
# ⚠️ Important: Never share your API key publicly! If you accidentally expose it, revoke it immediately and generate a new one.

# %% [markdown]
# ## Step 3: Build a Simple Chatbot

# %%
# Import necessary modules
import nest_asyncio

nest_asyncio.apply()
from llama_index.llms.groq import Groq
from llama_index.core.llms import ChatMessage

# %%
# Initialize the qroq model
llm = Groq(
    model="qwen/qwen3.6-27b",
)

# %%
async def simple_chatbot():
    """
    A simple interactive chatbot using groq with LlamaIndex.
    """
    print("🦙 Simple qroq Chatbot 🦙")
    print("Type 'exit' to end the conversation")
    print("-" * 50)

    # Initialize chat history
    messages = []

    while True:
        # Get user input
        user_input = input("\nYou: ")

        # Check for exit command
        if user_input.lower() in ["exit", "quit", "bye"]:
            print("\nChatbot: Goodbye! Have a great day!")
            break

        # Add user message to history
        messages.append(ChatMessage(role="user", content=user_input))

        try:
            # Get response from qroq

            response = llm.chat(messages)

            # Print the response
            print(f"\nChatbot: {response.message.content}")

            # Add assistant response to history
            messages.append(ChatMessage(role="assistant", content=response.message.content))

        except Exception as e:
            print(f"\nError: {e}")
            print("Please try again or check your API key")

# %%
# Run the chatbot
await simple_chatbot()
# Out:
# 🦙 Simple qroq Chatbot 🦙
# Type 'exit' to end the conversation
# --------------------------------------------------
#
# You: hi
#
# Chatbot:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user said "hi". This is a simple greeting.
# 2.  **Identify Intent:** The user is initiating a conversation. No specific question or task is provided.
# 3.  **Determine Response Strategy:**
#    - Acknowledge the greeting warmly
#    - Keep it open-ended to encourage further interaction
#    - Offer assistance
#    - Maintain a friendly, professional tone
# 4.  **Draft Response (Mental):** "Hi there! How can I help you today?" or "Hello! What's on your mind?" or "Hi! I'm here to help. What can I do for you?"
# 5.  **Refine Response:** Keep it concise and inviting. "Hi! How can I help you today?" works well.
# 6.  **Final Output Generation:** Match the refined response.✅
# </think>
#
# Hi! How can I help you today? 😊
#
# You: what's a dozen
#
# Chatbot:
# <think>
# ...
